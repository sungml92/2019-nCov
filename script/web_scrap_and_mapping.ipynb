# %% [markdown]
# # 2019-nCoV mapping
#
# ##### @sungml92
# ##### data source: Coronavirus 2019-nCoV Global Cases by Johns Hopkins CSSE
# ##### Google sheet api and google drive api code reference: http://bit.ly/386nKuk, http://bit.ly/2tDG12Z
#
# ### Coronavirus 2019-nCoV John Hopkins CSSE data import with google api
#
# #### I. import goolge sheet using google api

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials

scope = ['https://spreadsheets.google.com/feeds']#,'https://www.googleapis.com/auth/drive']

# credential is anonymised for privacy
cred_path_and_file = 'your_credential_please'

creds = ServiceAccountCredentials.from_json_keyfile_name(cred_path_and_file,scope)
client = gspread.authorize(creds)

# lazy approach retrieve by url
sheet = client.open_by_url('https://docs.google.com/spreadsheets/d/1wQVypefm946ch4XDp37uZ-wartW4V7ILdg-qYiDXUHM/htmlview?usp=sharing&sle=true#')
# or less lazy approach 
# sheet = client.open_by_key('1wQVypefm946ch4XDp37uZ-wartW4V7ILdg-qYiDXUHM')

# enter the number of the worksheet you wish to access. The number starts at 0
# by title also works when prompt worksheet = sheet.worksheet("name of work sheet")
# get the most recent record from url
worksheet = sheet.get_worksheet(0)

# %% [markdown]
# #### II. Beautify json output and json-table convert

# %%
import pprint
import pandas as pd

# check if data is correct
pp = pprint.PrettyPrinter()
nCoV = worksheet.get_all_records()
#pp.pprint(nCoV)

# open sheet with pd.DataFrame()
j2df = pd.DataFrame(nCoV)
# Out:
#     Confirmed        Country/Region  Deaths    Last Update    Province/State  \
# 0       22112        Mainland China     618   2/6/20 23:23             Hubei
# 1         970        Mainland China       0   2/6/20 12:43         Guangdong
# 2         954        Mainland China       0   2/6/20 10:53          Zhejiang
# 3         851        Mainland China       2   2/6/20 11:23             Henan
# 4         711        Mainland China       0   2/6/20 13:13             Hunan
# 5         600        Mainland China       0    2/6/20 2:33           Jiangxi
# 6         591        Mainland China       0   2/6/20 13:33             Anhui
# 7         411        Mainland China       2   2/6/20 23:33         Chongqing
# 8         373        Mainland China       0    2/6/20 8:03           Jiangsu
# 9         347        Mainland China       0    2/6/20 7:53          Shandong
# 10        344        Mainland China       1    2/7/20 0:53           Sichuan
# 11        274        Mainland China       1    2/6/20 3:23           Beijing
# 12        269        Mainland China       1    2/7/20 0:03          Shanghai
# 13        227        Mainland China       3    2/6/20 8:13      Heilongjiang
# 14        215        Mainland China       0   2/6/20 11:03            Fujian
# 15        173        Mainland China       0   2/6/20 13:53           Shaanxi
# 16        172        Mainland China       0    2/7/20 0:33           Guangxi
# 17        171        Mainland China       1    2/7/20 0:43             Hebei
# 18        133        Mainland China       0    2/6/20 9:43            Yunnan
# 19        106        Mainland China       2    2/7/20 0:03            Hainan
# 20         96        Mainland China       0   2/6/20 23:03            Shanxi
# 21         94        Mainland China       0   2/6/20 14:33          Liaoning
# 22         79        Mainland China       1   2/6/20 23:43           Tianjin
# 23         71        Mainland China       1    2/6/20 9:53           Guizhou
# 24         65        Mainland China       1    2/7/20 0:43             Jilin
# 25         62        Mainland China       0   2/5/20 16:23             Gansu
# 26         46        Mainland China       0    2/6/20 2:23    Inner Mongolia
# 27         45                 Japan       0    2/6/20 2:53
# 28         40        Mainland China       0    2/6/20 2:13           Ningxia
# 29         36        Mainland China       0    2/6/20 1:13          Xinjiang
# ..        ...                   ...     ...            ...               ...
# 41          5  United Arab Emirates       0    2/2/20 5:43
# 42          4             Australia       0    2/6/20 3:13   New South Wales
# 43          4             Australia       0    2/6/20 2:53        Queensland
# 44          4             Australia       0   2/1/20 18:12          Victoria
# 45          3                 India       0   2/3/20 21:43
# 46          2             Australia       0   2/2/20 22:33   South Australia
# 47          2                Canada       0   2/5/20 17:33  British Columbia
# 48          2                Canada       0    2/4/20 0:13       Toronto, ON
# 49          2                 Italy       0   1/31/20 8:15
# 50          2           Philippines       1    2/2/20 3:33
# 51          2                Russia       0  1/31/20 16:13
# 52          2                    UK       0    2/1/20 1:52
# 53          2                    US       0   2/1/20 19:43       Chicago, IL
# 54          2                    US       0    2/3/20 3:53    San Benito, CA
# 55          2                    US       0    2/3/20 0:43   Santa Clara, CA
# 56          1               Belgium       0   2/4/20 15:43
# 57          1              Cambodia       0   1/31/20 8:15
# 58          1                Canada       0    2/4/20 0:03        London, ON
# 59          1               Finland       0   1/31/20 8:15
# 60          1        Mainland China       0    2/1/20 1:52             Tibet
# 61          1                 Nepal       0   1/31/20 8:15
# 62          1                 Spain       0   2/1/20 23:43
# 63          1             Sri Lanka       0   1/31/20 8:15
# 64          1                Sweden       0    2/1/20 2:13
# 65          1                    US       0   2/1/20 19:43        Boston, MA
# 66          1                    US       0   2/1/20 19:53   Los Angeles, CA
# 67          1                    US       0   2/5/20 21:53       Madison, WI
# 68          1                    US       0   2/1/20 19:53        Orange, CA
# 69          1                    US       0   2/1/20 19:43       Seattle, WA
# 70          1                    US       0   2/1/20 19:43         Tempe, AZ
#
#     Recovered
# 0         817
# 1          69
# 2          94
# 3          56
# 4          81
# 5          37
# 6          34
# 7          24
# 8          34
# 9          27
# 10         37
# 11         31
# 12         25
# 13          8
# 14         14
# 15          9
# 16         17
# 17         16
# 18          7
# 19          8
# 20         12
# 21          5
# 22          2
# 23          6
# 24          4
# 25          6
# 26          4
# 27          1
# 28          1
# 29          0
# ..        ...
# 41          0
# 42          2
# 43          0
# 44          0
# 45          0
# 46          0
# 47          0
# 48          0
# 49          0
# 50          0
# 51          0
# 52          0
# 53          0
# 54          0
# 55          0
# 56          0
# 57          0
# 58          0
# 59          0
# 60          0
# 61          0
# 62          0
# 63          0
# 64          0
# 65          0
# 66          0
# 67          0
# 68          0
# 69          0
# 70          0
#
# [71 rows x 6 columns]

# %% [markdown]
# #### III. match latitude and longitude for Province and Country

# %%
from geopy.geocoders import Nominatim

j2df_v2 = j2df

for index in j2df.index:
    Country = j2df.iloc[index,1]
    State = j2df.iloc[index,4]
    
    # Avoid un-recognized geo-location format
    if State == Country:
        State = ""
    if Country == "Mainland China":
        Country = Country.split(" ")[1]

    place = State if len(State) != 0 else Country
    
    print("finding geolocation of %s %s" % (State, Country))
    try:
        geolocator = Nominatim(user_agent="geoloc_nCoV")
        location = geolocator.geocode(State+','+Country)
        print("latitude and longitude for %s %s is following" % (State, Country))
        print((location.latitude, location.longitude))
        
    except:
        print("cannot understand input State/Country, please check your format")
        break
    
    # add column for latitude and longitude
    print("adding latitude and longitude to new dataframe")
    j2df_v2.loc[j2df_v2.index[index], 'latitude'] = location.latitude
    j2df_v2.loc[j2df_v2.index[index], 'longitude'] = location.longitude
    j2df_v2.loc[j2df_v2.index[index], 'location'] = place
# Out:
# finding geolocation of Hubei China
# latitude and longitude for Hubei China is following
# (31.15172525, 112.87832224656043)
# adding latitude and longitude to new dataframe
# finding geolocation of Guangdong China
# latitude and longitude for Guangdong China is following
# (23.1357694, 113.1982688)
# adding latitude and longitude to new dataframe
# finding geolocation of Zhejiang China
# latitude and longitude for Zhejiang China is following
# (29.0000001, 119.9999999)
# adding latitude and longitude to new dataframe
# finding geolocation of Henan China
# latitude and longitude for Henan China is following
# (34.0000001, 113.9999999)
# adding latitude and longitude to new dataframe
# finding geolocation of Hunan China
# latitude and longitude for Hunan China is following
# (27.9995878, 112.009538)
# adding latitude and longitude to new dataframe
# finding geolocation of Jiangxi China
# latitude and longitude for Jiangxi China is following
# (28.0, 116.0)
# adding latitude and longitude to new dataframe
# finding geolocation of Anhui China
# latitude and longitude for Anhui China is following
# (32.0, 117.0)
# adding latitude and longitude to new dataframe
# finding geolocation of Chongqing China
# latitude and longitude for Chongqing China is following
# (30.05518, 107.8748712)
# adding latitude and longitude to new dataframe
# finding geolocation of Jiangsu China
# latitude and longitude for Jiangsu China is following
# (33.0000001, 119.9999999)
# adding latitude and longitude to new dataframe
# finding geolocation of Shandong China
# latitude and longitude for Shandong China is following
# (36.0000001, 118.9999999)
# adding latitude and longitude to new dataframe
# finding geolocation of Sichuan China
# latitude and longitude for Sichuan China is following
# (30.5000001, 102.4999999)
# adding latitude and longitude to new dataframe
# finding geolocation of Beijing China
# latitude and longitude for Beijing China is following
# (39.906217, 116.3912757)
# adding latitude and longitude to new dataframe
# finding geolocation of Shanghai China
# latitude and longitude for Shanghai China is following
# (31.2322758, 121.4692071)
# adding latitude and longitude to new dataframe
# finding geolocation of Heilongjiang China
# latitude and longitude for Heilongjiang China is following
# (48.0000047, 127.999992)
# adding latitude and longitude to new dataframe
# finding geolocation of Fujian China
# latitude and longitude for Fujian China is following
# (26.5450001, 117.842778)
# adding latitude and longitude to new dataframe
# finding geolocation of Shaanxi China
# latitude and longitude for Shaanxi China is following
# (36.0, 109.0)
# adding latitude and longitude to new dataframe
# finding geolocation of Guangxi China
# latitude and longitude for Guangxi China is following
# (24.0, 109.0)
# adding latitude and longitude to new dataframe
# finding geolocation of Hebei China
# latitude and longitude for Hebei China is following
# (39.0000001, 116.0)
# adding latitude and longitude to new dataframe
# finding geolocation of Yunnan China
# latitude and longitude for Yunnan China is following
# (25.0, 102.0)
# adding latitude and longitude to new dataframe
# finding geolocation of Hainan China
# latitude and longitude for Hainan China is following
# (19.2000001, 109.5999999)
# adding latitude and longitude to new dataframe
# finding geolocation of Shanxi China
# latitude and longitude for Shanxi China is following
# (37.0, 112.0)
# adding latitude and longitude to new dataframe
# finding geolocation of Liaoning China
# latitude and longitude for Liaoning China is following
# (40.9975197, 122.9955469)
# adding latitude and longitude to new dataframe
# finding geolocation of Tianjin China
# latitude and longitude for Tianjin China is following
# (39.1235635, 117.1980785)
# adding latitude and longitude to new dataframe
# finding geolocation of Guizhou China
# latitude and longitude for Guizhou China is following
# (27.0, 107.0)
# adding latitude and longitude to new dataframe
# finding geolocation of Jilin China
# latitude and longitude for Jilin China is following
# (42.9995032, 125.9816054)
# adding latitude and longitude to new dataframe
# finding geolocation of Gansu China
# latitude and longitude for Gansu China is following
# (38.0000001, 101.9999999)
# adding latitude and longitude to new dataframe
# finding geolocation of Inner Mongolia China
# latitude and longitude for Inner Mongolia China is following
# (43.2443242, 114.3251664)
# adding latitude and longitude to new dataframe
# finding geolocation of  Japan
# latitude and longitude for  Japan is following
# (36.5748441, 139.2394179)
# adding latitude and longitude to new dataframe
# finding geolocation of Ningxia China
# latitude and longitude for Ningxia China is following
# (37.0000001, 105.9999999)
# adding latitude and longitude to new dataframe
# finding geolocation of Xinjiang China
# latitude and longitude for Xinjiang China is following
# (41.7574769, 87.16738423046897)
# adding latitude and longitude to new dataframe
# finding geolocation of  Singapore
# latitude and longitude for  Singapore is following
# (1.357107, 103.8194992)
# adding latitude and longitude to new dataframe
# finding geolocation of  Thailand
# latitude and longitude for  Thailand is following
# (14.8971921, 100.83273)
# adding latitude and longitude to new dataframe
# finding geolocation of  Hong Kong
# latitude and longitude for  Hong Kong is following
# (22.2793278, 114.1628131)
# adding latitude and longitude to new dataframe
# finding geolocation of  South Korea
# latitude and longitude for  South Korea is following
# (36.5581914, 127.9408564)
# adding latitude and longitude to new dataframe
# finding geolocation of Qinghai China
# latitude and longitude for Qinghai China is following
# (35.40709525, 95.95211573241954)
# adding latitude and longitude to new dataframe
# finding geolocation of  Taiwan
# latitude and longitude for  Taiwan is following
# (23.9739374, 120.9820179)
# adding latitude and longitude to new dataframe
# finding geolocation of  Germany
# latitude and longitude for  Germany is following
# (51.0834196, 10.4234469)
# adding latitude and longitude to new dataframe
# finding geolocation of  Malaysia
# latitude and longitude for  Malaysia is following
# (4.5693754, 102.2656823)
# adding latitude and longitude to new dataframe
# finding geolocation of  Macau
# latitude and longitude for  Macau is following
# (22.1757605, 113.5514142)
# adding latitude and longitude to new dataframe
# finding geolocation of  Vietnam
# latitude and longitude for  Vietnam is following
# (13.2904027, 108.4265113)
# adding latitude and longitude to new dataframe
# finding geolocation of  France
# latitude and longitude for  France is following
# (46.603354, 1.8883335)
# adding latitude and longitude to new dataframe
# finding geolocation of  United Arab Emirates
# latitude and longitude for  United Arab Emirates is following
# (24.0002488, 53.9994829)
# adding latitude and longitude to new dataframe
# finding geolocation of New South Wales Australia
# latitude and longitude for New South Wales Australia is following
# (-31.8759835, 147.2869493)
# adding latitude and longitude to new dataframe
# finding geolocation of Queensland Australia
# latitude and longitude for Queensland Australia is following
# (-22.1646782, 144.5844903)
# adding latitude and longitude to new dataframe
# finding geolocation of Victoria Australia
# latitude and longitude for Victoria Australia is following
# (-36.5986096, 144.6780052)
# adding latitude and longitude to new dataframe
# finding geolocation of  India
# latitude and longitude for  India is following
# (22.3511148, 78.6677428)
# adding latitude and longitude to new dataframe
# finding geolocation of South Australia Australia
# latitude and longitude for South Australia Australia is following
# (-30.5343665, 135.6301212)
# adding latitude and longitude to new dataframe
# finding geolocation of British Columbia Canada
# latitude and longitude for British Columbia Canada is following
# (55.001251, -125.002441)
# adding latitude and longitude to new dataframe
# finding geolocation of Toronto, ON Canada
# latitude and longitude for Toronto, ON Canada is following
# (43.653963, -79.387207)
# adding latitude and longitude to new dataframe
# finding geolocation of  Italy
# latitude and longitude for  Italy is following
# (42.6384261, 12.674297)
# adding latitude and longitude to new dataframe
# finding geolocation of  Philippines
# latitude and longitude for  Philippines is following
# (12.7503486, 122.7312101)
# adding latitude and longitude to new dataframe
# finding geolocation of  Russia
# latitude and longitude for  Russia is following
# (64.6863136, 97.7453061)
# adding latitude and longitude to new dataframe
# finding geolocation of  UK
# latitude and longitude for  UK is following
# (54.7023545, -3.2765753)
# adding latitude and longitude to new dataframe
# finding geolocation of Chicago, IL US
# latitude and longitude for Chicago, IL US is following
# (41.8755616, -87.6244212)
# adding latitude and longitude to new dataframe
# finding geolocation of San Benito, CA US
# latitude and longitude for San Benito, CA US is following
# (36.6248089, -121.1177379)
# adding latitude and longitude to new dataframe
# finding geolocation of Santa Clara, CA US
# latitude and longitude for Santa Clara, CA US is following
# (37.2333253, -121.6846349)
# adding latitude and longitude to new dataframe
# finding geolocation of  Belgium
# latitude and longitude for  Belgium is following
# (50.6402809, 4.6667145)
# adding latitude and longitude to new dataframe
# finding geolocation of  Cambodia
# latitude and longitude for  Cambodia is following
# (13.5066394, 104.869423)
# adding latitude and longitude to new dataframe
# finding geolocation of London, ON Canada
# latitude and longitude for London, ON Canada is following
# (42.988576, -81.246643)
# adding latitude and longitude to new dataframe
# finding geolocation of  Finland
# latitude and longitude for  Finland is following
# (63.2467777, 25.9209164)
# adding latitude and longitude to new dataframe
# finding geolocation of Tibet China
# latitude and longitude for Tibet China is following
# (31.894343149999997, 87.07813712706509)
# adding latitude and longitude to new dataframe
# finding geolocation of  Nepal
# latitude and longitude for  Nepal is following
# (28.1083929, 84.0917139)
# adding latitude and longitude to new dataframe
# finding geolocation of  Spain
# latitude and longitude for  Spain is following
# (39.3262345, -4.8380649)
# adding latitude and longitude to new dataframe
# finding geolocation of  Sri Lanka
# latitude and longitude for  Sri Lanka is following
# (7.5554942, 80.7137847)
# adding latitude and longitude to new dataframe
# finding geolocation of  Sweden
# latitude and longitude for  Sweden is following
# (59.6749712, 14.5208584)
# adding latitude and longitude to new dataframe
# finding geolocation of Boston, MA US
# latitude and longitude for Boston, MA US is following
# (42.3602534, -71.0582912)
# adding latitude and longitude to new dataframe
# finding geolocation of Los Angeles, CA US
# latitude and longitude for Los Angeles, CA US is following
# (34.0536909, -118.2427666)
# adding latitude and longitude to new dataframe
# finding geolocation of Madison, WI US
# latitude and longitude for Madison, WI US is following
# (43.074761, -89.3837613)
# adding latitude and longitude to new dataframe
# finding geolocation of Orange, CA US
# latitude and longitude for Orange, CA US is following
# (33.7500378, -117.8704931)
# adding latitude and longitude to new dataframe
# finding geolocation of Seattle, WA US
# latitude and longitude for Seattle, WA US is following
# (47.6038321, -122.3300624)
# adding latitude and longitude to new dataframe
# finding geolocation of Tempe, AZ US
# latitude and longitude for Tempe, AZ US is following
# (33.4255056, -111.9400125)
# adding latitude and longitude to new dataframe

# %% [markdown]
# #### Now time to map! Happy mapping

# %%
import folium
import pandas as pd
    
# Make an empty map
m = folium.Map([20, 20], zoom_start=2)

# I can add marker one by one on the map
for i in range(0,len(j2df_v2)):
    folium.Circle(
    location=[j2df_v2.iloc[i]['latitude'],j2df_v2.iloc[i]['longitude']],
    popup=j2df_v2.iloc[i]['location'],
    radius=float(j2df_v2.iloc[i]['Confirmed']*10),
    color='crimson',
    fill=True,
    fill_color='crimson'
   ).add_to(m)

# Save it as html
m.save('2019-nCoV_map_JHUCSSEdata_02072020.html')
